# %%
import pandas as pd
import numpy as np
import 
# test function, later will merge with normal function
def preprocess_text(text):
    text = text[1]
    return text


df = pd.read_csv('tagged.txt', sep='<\d*>')
pub = df['citates']

# partition removal
df['citates'] = pub.str.lstrip( '<|startoftext|>'  )
df['citates'] = pub.str.rstrip( '<|endoftext|>'  )


# add column with processed text
df['processed citates'] = df['citates'].apply(preprocess_text)


df
# Out:
# /home/alex/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#                                                  citates processed citates
# 0      Выкинь все, что есть в твоих мыслях: грусть, п...                 ы
# 1      Пока не научишься ценить то, что есть – никогд...                 о
# 2      Порой молчание, красноречивее любых произнесен...                 о
# 3                    Книга "Память души" (Ника Остожева)                 н
# 4      А вы знаете, жизнь ведь замечательна и удивите...
# ...                                                  ...               ...
# 16999  Величайшая твердость и есть величайшее милосер...                 е
# ...
